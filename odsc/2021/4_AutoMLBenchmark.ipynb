# %% [markdown]
# # The Open Source AutoML Benchmark
# This notebook features a minimal introduction to the open source automl benchmark.
# Please refer to the documentation of the benchmark framework itself for how to install and use it.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Frameworks
#
#  - AutoGluon
#  - AutoWEKA
#  - Auto-sklearn
#  - Auto-xgboost
#  - GAMA
#  - H2O
#  - Light AutoML
#  - MLJar Supervised
#  - ML-Plan
#  - TPOT

# %% [markdown]
# ## OpenML Integration
# But local files can be used as well.

# %% [markdown]
# ## Run locally, in a container, or on AWS

# %% [markdown]
# ```
# python runbenchmark.py tpot openml/t/6
# python runbenchmark.py tpot openml/t/6 -m docker
# python runbenchmark.py tpot openml/t/6 -m aws
# ```

# %% [markdown]
# ```
#                      id                     task          framework constraint fold   result   metric
# 0     openml.org/t/9910              bioresponse  constantpredictor       test    0  0.50000      auc
# 1     openml.org/t/9910              bioresponse  constantpredictor       test    1  0.50000      auc
# 2   openml.org/t/125920            dresses-sales  constantpredictor       test    0  0.50000      auc
# 3   openml.org/t/125920            dresses-sales  constantpredictor       test    1  0.50000      auc
# 4     openml.org/t/2079               eucalyptus  constantpredictor       test    0  1.57384  logloss
# 5     openml.org/t/2079               eucalyptus  constantpredictor       test    1  1.57384  logloss
# 6   openml.org/t/167125  internet-advertisements  constantpredictor       test    0  0.50000      auc
# 7   openml.org/t/167125  internet-advertisements  constantpredictor       test    1  0.50000      auc
# 8     openml.org/t/9950               micro-mass  constantpredictor       test    0  2.91733  logloss
# 9     openml.org/t/9950               micro-mass  constantpredictor       test    1  2.90634  logloss
# 10    openml.org/t/3917                      kc1  constantpredictor       test    0  0.50000      auc
# 11    openml.org/t/3917                      kc1  constantpredictor       test    1  0.50000      auc
# 12  openml.org/t/168868               APSFailure  constantpredictor       test    0  0.50000      auc
# 13  openml.org/t/168868               APSFailure  constantpredictor       test    1  0.50000      auc
# ```

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Any questions, feedback, or feature requests? Reach out!

# %% [markdown]
# When you are using the software shown in this presentation (`openml-python`, `gama` or the benchmark framework),you might find yourself with a question, something that could be improved, or a feature you miss. Please do reach out! The best way is to open an issue on the respective repository. We're there to get you started, and any feedback is invaluable to ensure the tools can be enjoyed by anyone! :)
